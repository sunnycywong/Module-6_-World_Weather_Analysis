# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import gmaps
import requests
from datetime import datetime

# Import the time module.
import time

# Import the API key.
from config import g_key

# Import the API key.
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
#Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Get the nearest city using the citipy module.

# Use the citipy module to determine city based on latitude and longitude.
#from citipy import citipy

# %%
#Get the nearest city using the citipy module.

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
#Perform an API call with the OpenWeatherMap.
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7289887da70056aba2314bd34aaab29f

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sal rei
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | chegem
# Processing Record 4 of Set 1 | hami
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | harrison
# Processing Record 8 of Set 1 | maragogi
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | bandarbeyla
# Processing Record 12 of Set 1 | sola
# Processing Record 13 of Set 1 | ancud
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | shubarshi
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 1 | neka
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | anito
# Processing Record 21 of Set 1 | wanning
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 1 | kahului
# Processing Record 25 of Set 1 | umm kaddadah
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | alihe
# Processing Record 28 of Set 1 | bubaque
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | bhatkal
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | khatanga
# Processing Record 34 of Set 1 | xinyang
# Processing Record 35 of Set 1 | touros
# Processing Record 36 of Set 1 | ndele
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | geraldton
# Processing Record 39 of Set 1 | coihaique
# Processing Record 40 of Set 1 | akdepe
# Processing Record 41 of Set 1 | terney
# Processing Record 42 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | paamiut
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | carnarvon
# Processing Record 47 of Set 1 | urubicha
# Processing Record 48 of Set 1 | amapa
# Processing Record 49 of Set 1 | panuco
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | manakara
# Processing Record 2 of Set 2 | te anau
# Processing Record 3 of Set 2 | barra do garcas
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | hauterive
# Processing Record 6 of Set 2 | yeppoon
# Processing Record 7 of Set 2 | daru
# Processing Record 8 of Set 2 | evensk
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | kelowna
# Processing Record 11 of Set 2 | anadyr
# Processing Record 12 of Set 2 | bengkulu
# Processing Record 13 of Set 2 | saint george
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | cam pha
# City not found. Skipping...
# Processing Record 16 of Set 2 | khandyga
# Processing Record 17 of Set 2 | plettenberg bay
# Processing Record 18 of Set 2 | arraial do cabo
# Processing Record 19 of Set 2 | mgachi
# Processing Record 20 of Set 2 | mahebourg
# Processing Record 21 of Set 2 | wichita
# Processing Record 22 of Set 2 | chokurdakh
# Processing Record 23 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 24 of Set 2 | salas
# Processing Record 25 of Set 2 | punta arenas
# Processing Record 26 of Set 2 | norman wells
# Processing Record 27 of Set 2 | bethel
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | manggar
# Processing Record 31 of Set 2 | goedereede
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | yellowknife
# Processing Record 34 of Set 2 | reconquista
# Processing Record 35 of Set 2 | bakchar
# Processing Record 36 of Set 2 | thunder bay
# Processing Record 37 of Set 2 | chuy
# Processing Record 38 of Set 2 | kununurra
# Processing Record 39 of Set 2 | asau
# Processing Record 40 of Set 2 | santa cruz
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | lorengau
# Processing Record 43 of Set 2 | tiksi
# Processing Record 44 of Set 2 | naze
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | puerto ayacucho
# Processing Record 47 of Set 2 | morgantown
# Processing Record 48 of Set 2 | iasmos
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | chingirlau
# Processing Record 1 of Set 3 | edson
# Processing Record 2 of Set 3 | athens
# Processing Record 3 of Set 3 | souillac
# Processing Record 4 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 3 | la rioja
# Processing Record 6 of Set 3 | ponta do sol
# Processing Record 7 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 3 | hervey bay
# Processing Record 9 of Set 3 | olga
# Processing Record 10 of Set 3 | duluth
# Processing Record 11 of Set 3 | aklavik
# Processing Record 12 of Set 3 | mataura
# Processing Record 13 of Set 3 | langenburg
# Processing Record 14 of Set 3 | rawson
# Processing Record 15 of Set 3 | isangel
# Processing Record 16 of Set 3 | lagoa
# Processing Record 17 of Set 3 | port elizabeth
# Processing Record 18 of Set 3 | ostrovnoy
# Processing Record 19 of Set 3 | inhambane
# Processing Record 20 of Set 3 | sao filipe
# Processing Record 21 of Set 3 | srednekolymsk
# Processing Record 22 of Set 3 | klaksvik
# Processing Record 23 of Set 3 | sovetskaya gavan
# Processing Record 24 of Set 3 | victoria point
# Processing Record 25 of Set 3 | port lincoln
# Processing Record 26 of Set 3 | pervomayskoye
# Processing Record 27 of Set 3 | pyshchug
# Processing Record 28 of Set 3 | cayenne
# Processing Record 29 of Set 3 | vanimo
# Processing Record 30 of Set 3 | progreso
# Processing Record 31 of Set 3 | santana
# Processing Record 32 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 3 | vardo
# Processing Record 35 of Set 3 | portland
# Processing Record 36 of Set 3 | usinsk
# Processing Record 37 of Set 3 | provideniya
# Processing Record 38 of Set 3 | caravelas
# Processing Record 39 of Set 3 | los llanos de aridane
# Processing Record 40 of Set 3 | cabo san lucas
# Processing Record 41 of Set 3 | ordzhonikidze
# Processing Record 42 of Set 3 | praia da vitoria
# Processing Record 43 of Set 3 | dicabisagan
# Processing Record 44 of Set 3 | port-gentil
# Processing Record 45 of Set 3 | barbosa ferraz
# Processing Record 46 of Set 3 | jiayuguan
# Processing Record 47 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 3 | kupang
# Processing Record 49 of Set 3 | acahay
# Processing Record 50 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 1 of Set 4 | tasiilaq
# Processing Record 2 of Set 4 | mbekenyera
# Processing Record 3 of Set 4 | katsuura
# Processing Record 4 of Set 4 | krapivinskiy
# Processing Record 5 of Set 4 | faya
# Processing Record 6 of Set 4 | diego de almagro
# Processing Record 7 of Set 4 | gulshat
# City not found. Skipping...
# Processing Record 8 of Set 4 | ust-nera
# Processing Record 9 of Set 4 | grindavik
# Processing Record 10 of Set 4 | awjilah
# Processing Record 11 of Set 4 | kharp
# Processing Record 12 of Set 4 | saldanha
# Processing Record 13 of Set 4 | kostino
# Processing Record 14 of Set 4 | chapais
# Processing Record 15 of Set 4 | auki
# Processing Record 16 of Set 4 | fort nelson
# Processing Record 17 of Set 4 | cidreira
# Processing Record 18 of Set 4 | sur
# Processing Record 19 of Set 4 | bay saint louis
# Processing Record 20 of Set 4 | salym
# Processing Record 21 of Set 4 | zheleznodorozhnyy
# Processing Record 22 of Set 4 | eureka
# Processing Record 23 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 4 | acapulco
# Processing Record 25 of Set 4 | nikolskoye
# Processing Record 26 of Set 4 | aksu
# Processing Record 27 of Set 4 | wilmington
# Processing Record 28 of Set 4 | mosquera
# Processing Record 29 of Set 4 | avarua
# Processing Record 30 of Set 4 | georgetown
# Processing Record 31 of Set 4 | saint anthony
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | tumsar
# Processing Record 34 of Set 4 | yambio
# Processing Record 35 of Set 4 | hithadhoo
# Processing Record 36 of Set 4 | janauba
# Processing Record 37 of Set 4 | san andres
# Processing Record 38 of Set 4 | fuxin
# Processing Record 39 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 40 of Set 4 | moerai
# Processing Record 41 of Set 4 | jamestown
# Processing Record 42 of Set 4 | arman
# Processing Record 43 of Set 4 | luderitz
# Processing Record 44 of Set 4 | mount gambier
# Processing Record 45 of Set 4 | pevek
# Processing Record 46 of Set 4 | chernyshevskiy
# Processing Record 47 of Set 4 | cherskiy
# Processing Record 48 of Set 4 | broken hill
# Processing Record 49 of Set 4 | fortuna
# Processing Record 50 of Set 4 | roald
# Processing Record 1 of Set 5 | kolvereid
# Processing Record 2 of Set 5 | orlik
# Processing Record 3 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 5 | soyo
# Processing Record 5 of Set 5 | longyearbyen
# Processing Record 6 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 5 | waipawa
# Processing Record 8 of Set 5 | alice springs
# Processing Record 9 of Set 5 | valley city
# Processing Record 10 of Set 5 | graham
# Processing Record 11 of Set 5 | sitka
# Processing Record 12 of Set 5 | maniitsoq
# Processing Record 13 of Set 5 | lahij
# Processing Record 14 of Set 5 | butembo
# Processing Record 15 of Set 5 | chitungwiza
# Processing Record 16 of Set 5 | pacific grove
# Processing Record 17 of Set 5 | lagunas
# Processing Record 18 of Set 5 | acajutla
# Processing Record 19 of Set 5 | dakar
# Processing Record 20 of Set 5 | vestmannaeyjar
# Processing Record 21 of Set 5 | mahanoro
# Processing Record 22 of Set 5 | yerbogachen
# Processing Record 23 of Set 5 | lompoc
# Processing Record 24 of Set 5 | bloomfield
# Processing Record 25 of Set 5 | moa
# Processing Record 26 of Set 5 | nago
# Processing Record 27 of Set 5 | dikson
# Processing Record 28 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 29 of Set 5 | yulara
# Processing Record 30 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 5 | rhondda
# Processing Record 32 of Set 5 | nueve de julio
# Processing Record 33 of Set 5 | nuevo progreso
# Processing Record 34 of Set 5 | shevchenkove
# Processing Record 35 of Set 5 | taikang
# Processing Record 36 of Set 5 | faanui
# Processing Record 37 of Set 5 | paita
# Processing Record 38 of Set 5 | yerky
# Processing Record 39 of Set 5 | upernavik
# Processing Record 40 of Set 5 | alekseyevka
# Processing Record 41 of Set 5 | quatre cocos
# Processing Record 42 of Set 5 | tome-acu
# City not found. Skipping...
# Processing Record 43 of Set 5 | kuroiso
# Processing Record 44 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 45 of Set 5 | taloqan
# Processing Record 46 of Set 5 | onega
# Processing Record 47 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 5 | broome
# Processing Record 49 of Set 5 | dawlatabad
# Processing Record 50 of Set 5 | fort frances
# Processing Record 1 of Set 6 | negara
# Processing Record 2 of Set 6 | dzhebariki-khaya
# Processing Record 3 of Set 6 | tuatapere
# Processing Record 4 of Set 6 | coahuayana
# Processing Record 5 of Set 6 | westport
# Processing Record 6 of Set 6 | tautira
# Processing Record 7 of Set 6 | utrecht
# Processing Record 8 of Set 6 | mwinilunga
# Processing Record 9 of Set 6 | perigueux
# Processing Record 10 of Set 6 | kamaishi
# Processing Record 11 of Set 6 | moctezuma
# Processing Record 12 of Set 6 | marawi
# Processing Record 13 of Set 6 | ahipara
# Processing Record 14 of Set 6 | miquelon
# Processing Record 15 of Set 6 | nemuro
# Processing Record 16 of Set 6 | huntsville
# Processing Record 17 of Set 6 | anshun
# Processing Record 18 of Set 6 | east london
# Processing Record 19 of Set 6 | rabo de peixe
# Processing Record 20 of Set 6 | matara
# Processing Record 21 of Set 6 | guhagar
# Processing Record 22 of Set 6 | oussouye
# Processing Record 23 of Set 6 | udachnyy
# Processing Record 24 of Set 6 | lyuban
# Processing Record 25 of Set 6 | saskylakh
# Processing Record 26 of Set 6 | namibe
# Processing Record 27 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 6 | bathsheba
# Processing Record 29 of Set 6 | santarem
# Processing Record 30 of Set 6 | barranca
# Processing Record 31 of Set 6 | great falls
# Processing Record 32 of Set 6 | abu dhabi
# Processing Record 33 of Set 6 | ijui
# Processing Record 34 of Set 6 | anloga
# Processing Record 35 of Set 6 | burnie
# Processing Record 36 of Set 6 | benjamin hill
# Processing Record 37 of Set 6 | tiruvottiyur
# City not found. Skipping...
# Processing Record 38 of Set 6 | vilhena
# Processing Record 39 of Set 6 | flin flon
# Processing Record 40 of Set 6 | nkayi
# Processing Record 41 of Set 6 | morro bay
# Processing Record 42 of Set 6 | natal
# Processing Record 43 of Set 6 | xining
# Processing Record 44 of Set 6 | najran
# Processing Record 45 of Set 6 | acari
# Processing Record 46 of Set 6 | zhaoyuan
# Processing Record 47 of Set 6 | kudahuvadhoo
# Processing Record 48 of Set 6 | polunochnoye
# Processing Record 49 of Set 6 | petukhovo
# Processing Record 50 of Set 6 | tena
# Processing Record 1 of Set 7 | west plains
# Processing Record 2 of Set 7 | maumere
# Processing Record 3 of Set 7 | kavieng
# Processing Record 4 of Set 7 | churapcha
# Processing Record 5 of Set 7 | malartic
# Processing Record 6 of Set 7 | arroyohondo
# Processing Record 7 of Set 7 | xichang
# Processing Record 8 of Set 7 | pacasmayo
# Processing Record 9 of Set 7 | vidim
# Processing Record 10 of Set 7 | grenaa
# Processing Record 11 of Set 7 | alofi
# Processing Record 12 of Set 7 | lavrentiya
# Processing Record 13 of Set 7 | clyde river
# Processing Record 14 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 15 of Set 7 | matagami
# Processing Record 16 of Set 7 | sulangan
# Processing Record 17 of Set 7 | high rock
# Processing Record 18 of Set 7 | fernandina beach
# Processing Record 19 of Set 7 | belaya gora
# Processing Record 20 of Set 7 | mandalgovi
# Processing Record 21 of Set 7 | nelson bay
# Processing Record 22 of Set 7 | the pas
# Processing Record 23 of Set 7 | agadir
# Processing Record 24 of Set 7 | codrington
# Processing Record 25 of Set 7 | saleilua
# City not found. Skipping...
# Processing Record 26 of Set 7 | malakal
# Processing Record 27 of Set 7 | ilulissat
# Processing Record 28 of Set 7 | chicama
# Processing Record 29 of Set 7 | san patricio
# Processing Record 30 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 7 | meulaboh
# Processing Record 32 of Set 7 | kieta
# Processing Record 33 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 7 | guaymas
# Processing Record 35 of Set 7 | shelbyville
# Processing Record 36 of Set 7 | port macquarie
# Processing Record 37 of Set 7 | port hedland
# Processing Record 38 of Set 7 | vila franca do campo
# Processing Record 39 of Set 7 | tupiza
# Processing Record 40 of Set 7 | castro
# Processing Record 41 of Set 7 | harper
# Processing Record 42 of Set 7 | banyumas
# Processing Record 43 of Set 7 | beni suef
# Processing Record 44 of Set 7 | rocha
# Processing Record 45 of Set 7 | constitucion
# Processing Record 46 of Set 7 | oranjemund
# Processing Record 47 of Set 7 | nabire
# Processing Record 48 of Set 7 | ugep
# Processing Record 49 of Set 7 | college
# Processing Record 50 of Set 7 | gravdal
# Processing Record 1 of Set 8 | khrenovoye
# Processing Record 2 of Set 8 | atar
# Processing Record 3 of Set 8 | krasnorechenskiy
# Processing Record 4 of Set 8 | narsaq
# Processing Record 5 of Set 8 | gazanjyk
# Processing Record 6 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 7 of Set 8 | zhicheng
# Processing Record 8 of Set 8 | labytnangi
# Processing Record 9 of Set 8 | poum
# Processing Record 10 of Set 8 | ambulu
# Processing Record 11 of Set 8 | kaitangata
# Processing Record 12 of Set 8 | coventry
# Processing Record 13 of Set 8 | matthews
# Processing Record 14 of Set 8 | corquin
# Processing Record 15 of Set 8 | peace river
# Processing Record 16 of Set 8 | bassila
# Processing Record 17 of Set 8 | torbay
# Processing Record 18 of Set 8 | beira
# Processing Record 19 of Set 8 | mahibadhoo
# Processing Record 20 of Set 8 | puerto maldonado
# Processing Record 21 of Set 8 | along
# Processing Record 22 of Set 8 | cap malheureux
# Processing Record 23 of Set 8 | konevo
# Processing Record 24 of Set 8 | korla
# Processing Record 25 of Set 8 | gamba
# Processing Record 26 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 8 | benghazi
# Processing Record 28 of Set 8 | krasnyy yar
# Processing Record 29 of Set 8 | north bend
# Processing Record 30 of Set 8 | hamilton
# Processing Record 31 of Set 8 | la salle
# Processing Record 32 of Set 8 | san quintin
# Processing Record 33 of Set 8 | chipinge
# Processing Record 34 of Set 8 | neftcala
# Processing Record 35 of Set 8 | tezu
# Processing Record 36 of Set 8 | moog
# Processing Record 37 of Set 8 | palaion ayionerion
# City not found. Skipping...
# Processing Record 38 of Set 8 | samana
# Processing Record 39 of Set 8 | talnakh
# Processing Record 40 of Set 8 | esperance
# Processing Record 41 of Set 8 | salalah
# Processing Record 42 of Set 8 | noumea
# Processing Record 43 of Set 8 | tanda
# Processing Record 44 of Set 8 | makinsk
# Processing Record 45 of Set 8 | ulaanbaatar
# Processing Record 46 of Set 8 | dunedin
# Processing Record 47 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 48 of Set 8 | hermitage
# Processing Record 49 of Set 8 | kutum
# Processing Record 50 of Set 8 | tiznit
# Processing Record 1 of Set 9 | leningradskiy
# Processing Record 2 of Set 9 | patnos
# Processing Record 3 of Set 9 | muros
# Processing Record 4 of Set 9 | mishan
# Processing Record 5 of Set 9 | sao joao do paraiso
# Processing Record 6 of Set 9 | olavarria
# Processing Record 7 of Set 9 | dahra
# Processing Record 8 of Set 9 | kargil
# Processing Record 9 of Set 9 | lawrenceburg
# Processing Record 10 of Set 9 | karasburg
# Processing Record 11 of Set 9 | sangar
# Processing Record 12 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 9 | balikpapan
# Processing Record 14 of Set 9 | antiguo morelos
# Processing Record 15 of Set 9 | bambous virieux
# Processing Record 16 of Set 9 | padang
# Processing Record 17 of Set 9 | bereda
# Processing Record 18 of Set 9 | iqaluit
# Processing Record 19 of Set 9 | nara
# Processing Record 20 of Set 9 | montague
# Processing Record 21 of Set 9 | kazachinskoye
# Processing Record 22 of Set 9 | pisco
# Processing Record 23 of Set 9 | finschhafen
# Processing Record 24 of Set 9 | buraydah
# Processing Record 25 of Set 9 | port blair
# Processing Record 26 of Set 9 | naples
# Processing Record 27 of Set 9 | lebu
# Processing Record 28 of Set 9 | gayny
# Processing Record 29 of Set 9 | rio claro
# Processing Record 30 of Set 9 | fairbanks
# Processing Record 31 of Set 9 | neuquen
# Processing Record 32 of Set 9 | punta alta
# Processing Record 33 of Set 9 | kruisfontein
# Processing Record 34 of Set 9 | nishihara
# Processing Record 35 of Set 9 | sohag
# Processing Record 36 of Set 9 | kemijarvi
# Processing Record 37 of Set 9 | avera
# Processing Record 38 of Set 9 | emba
# Processing Record 39 of Set 9 | marabba
# Processing Record 40 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 9 | beringovskiy
# Processing Record 42 of Set 9 | viedma
# Processing Record 43 of Set 9 | karpogory
# Processing Record 44 of Set 9 | port-de-paix
# City not found. Skipping...
# Processing Record 45 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 46 of Set 9 | oudtshoorn
# Processing Record 47 of Set 9 | takaka
# Processing Record 48 of Set 9 | okhotsk
# Processing Record 49 of Set 9 | uribia
# Processing Record 50 of Set 9 | rio blanco
# Processing Record 1 of Set 10 | mount pleasant
# Processing Record 2 of Set 10 | kokkola
# Processing Record 3 of Set 10 | ballina
# Processing Record 4 of Set 10 | beloha
# Processing Record 5 of Set 10 | kalmunai
# Processing Record 6 of Set 10 | blind river
# Processing Record 7 of Set 10 | buala
# Processing Record 8 of Set 10 | bonavista
# Processing Record 9 of Set 10 | san antero
# Processing Record 10 of Set 10 | airai
# Processing Record 11 of Set 10 | abadan
# Processing Record 12 of Set 10 | talara
# Processing Record 13 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 14 of Set 10 | phalaborwa
# Processing Record 15 of Set 10 | saint-joseph
# Processing Record 16 of Set 10 | afmadu
# City not found. Skipping...
# Processing Record 17 of Set 10 | erdenet
# Processing Record 18 of Set 10 | fort-shevchenko
# Processing Record 19 of Set 10 | lianzhou
# Processing Record 20 of Set 10 | sarkand
# Processing Record 21 of Set 10 | binga
# Processing Record 22 of Set 10 | grootfontein
# Processing Record 23 of Set 10 | laguna
# Processing Record 24 of Set 10 | koshurnikovo
# Processing Record 25 of Set 10 | pietersburg
# Processing Record 26 of Set 10 | vila velha
# Processing Record 27 of Set 10 | roros
# Processing Record 28 of Set 10 | vestmanna
# Processing Record 29 of Set 10 | ulladulla
# Processing Record 30 of Set 10 | sabha
# Processing Record 31 of Set 10 | tigil
# Processing Record 32 of Set 10 | olinda
# Processing Record 33 of Set 10 | flinders
# Processing Record 34 of Set 10 | port hawkesbury
# Processing Record 35 of Set 10 | shimoda
# Processing Record 36 of Set 10 | la ronge
# Processing Record 37 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 10 | misawa
# Processing Record 39 of Set 10 | surt
# Processing Record 40 of Set 10 | bonthe
# Processing Record 41 of Set 10 | prince rupert
# Processing Record 42 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 10 | zhigansk
# Processing Record 44 of Set 10 | soma
# Processing Record 45 of Set 10 | ukhta
# Processing Record 46 of Set 10 | dingle
# Processing Record 47 of Set 10 | yanam
# Processing Record 48 of Set 10 | zemlyansk
# Processing Record 49 of Set 10 | krasnoselkup
# Processing Record 50 of Set 10 | hoquiam
# Processing Record 1 of Set 11 | nouadhibou
# Processing Record 2 of Set 11 | svetlogorsk
# Processing Record 3 of Set 11 | rosarito
# Processing Record 4 of Set 11 | guerrero negro
# Processing Record 5 of Set 11 | tessalit
# Processing Record 6 of Set 11 | la serena
# Processing Record 7 of Set 11 | brandon
# Processing Record 8 of Set 11 | sept-iles
# Processing Record 9 of Set 11 | jumla
# Processing Record 10 of Set 11 | requena
# Processing Record 11 of Set 11 | sao joao da barra
# Processing Record 12 of Set 11 | sobolevo
# Processing Record 13 of Set 11 | lewiston
# Processing Record 14 of Set 11 | pauri
# Processing Record 15 of Set 11 | bhilwara
# Processing Record 16 of Set 11 | mount isa
# Processing Record 17 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 18 of Set 11 | yaan
# Processing Record 19 of Set 11 | abay
# Processing Record 20 of Set 11 | port shepstone
# Processing Record 21 of Set 11 | arlit
# Processing Record 22 of Set 11 | koslan
# Processing Record 23 of Set 11 | monkey bay
# Processing Record 24 of Set 11 | ferrara
# Processing Record 25 of Set 11 | lardos
# Processing Record 26 of Set 11 | leh
# Processing Record 27 of Set 11 | price
# Processing Record 28 of Set 11 | knysna
# Processing Record 29 of Set 11 | isla vista
# Processing Record 30 of Set 11 | jiroft
# City not found. Skipping...
# Processing Record 31 of Set 11 | whitehorse
# Processing Record 32 of Set 11 | altamont
# Processing Record 33 of Set 11 | el dorado
# Processing Record 34 of Set 11 | gwadar
# Processing Record 35 of Set 11 | dongsheng
# Processing Record 36 of Set 11 | kaohsiung
# Processing Record 37 of Set 11 | cherkasskoye
# Processing Record 38 of Set 11 | peniche
# Processing Record 39 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 11 | marsh harbour
# Processing Record 41 of Set 11 | grand-santi
# Processing Record 42 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 11 | hagerstown
# Processing Record 45 of Set 11 | victoria
# Processing Record 46 of Set 11 | svetlyy
# Processing Record 47 of Set 11 | wuchi
# Processing Record 48 of Set 11 | central point
# Processing Record 49 of Set 11 | bluefield
# Processing Record 50 of Set 11 | barao de melgaco
# Processing Record 1 of Set 12 | yar-sale
# Processing Record 2 of Set 12 | alasehir
# Processing Record 3 of Set 12 | santiago del estero
# Processing Record 4 of Set 12 | piryion
# City not found. Skipping...
# Processing Record 5 of Set 12 | lubao
# Processing Record 6 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 12 | kawalu
# Processing Record 8 of Set 12 | barcelos
# Processing Record 9 of Set 12 | kargasok
# Processing Record 10 of Set 12 | yinchuan
# Processing Record 11 of Set 12 | pundaguitan
# Processing Record 12 of Set 12 | tabuny
# Processing Record 13 of Set 12 | huarmey
# Processing Record 14 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 15 of Set 12 | kaeo
# Processing Record 16 of Set 12 | maldonado
# Processing Record 17 of Set 12 | vanavara
# Processing Record 18 of Set 12 | okha
# Processing Record 19 of Set 12 | labuhan
# Processing Record 20 of Set 12 | am timan
# Processing Record 21 of Set 12 | shache
# Processing Record 22 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 12 | lazaro cardenas
# Processing Record 24 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 25 of Set 12 | pedernales
# Processing Record 26 of Set 12 | prieska
# Processing Record 27 of Set 12 | hobyo
# Processing Record 28 of Set 12 | dukat
# Processing Record 29 of Set 12 | kayerkan
# Processing Record 30 of Set 12 | baykit
# Processing Record 31 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 32 of Set 12 | lata
# Processing Record 33 of Set 12 | puro
# Processing Record 34 of Set 12 | kendari
# Processing Record 35 of Set 12 | dobroye
# Processing Record 36 of Set 12 | mildura
# Processing Record 37 of Set 12 | loa janan
# Processing Record 38 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 39 of Set 12 | huilong
# Processing Record 40 of Set 12 | elizabeth city
# Processing Record 41 of Set 12 | tottori
# Processing Record 42 of Set 12 | houston
# Processing Record 43 of Set 12 | maues
# Processing Record 44 of Set 12 | yubari
# Processing Record 45 of Set 12 | komsomolskiy
# Processing Record 46 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 12 | antofagasta
# Processing Record 48 of Set 12 | zavetnoye
# Processing Record 49 of Set 12 | kangundo
# Processing Record 50 of Set 12 | kloulklubed
# Processing Record 1 of Set 13 | riyadh
# Processing Record 2 of Set 13 | nome
# Processing Record 3 of Set 13 | strezhevoy
# Processing Record 4 of Set 13 | mantua
# Processing Record 5 of Set 13 | camana
# Processing Record 6 of Set 13 | san cristobal
# Processing Record 7 of Set 13 | kitui
# Processing Record 8 of Set 13 | tashigang
# Processing Record 9 of Set 13 | murmashi
# Processing Record 10 of Set 13 | kautokeino
# Processing Record 11 of Set 13 | hasaki
# Processing Record 12 of Set 13 | sakete
# Processing Record 13 of Set 13 | opuwo
# Processing Record 14 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 15 of Set 13 | gat
# Processing Record 16 of Set 13 | languyan
# Processing Record 17 of Set 13 | necochea
# Processing Record 18 of Set 13 | basay
# Processing Record 19 of Set 13 | ilo
# Processing Record 20 of Set 13 | takoradi
# Processing Record 21 of Set 13 | cozumel
# Processing Record 22 of Set 13 | pitimbu
# Processing Record 23 of Set 13 | luangwa
# Processing Record 24 of Set 13 | hirara
# Processing Record 25 of Set 13 | imbituba
# Processing Record 26 of Set 13 | zambezi
# Processing Record 27 of Set 13 | ketchikan
# Processing Record 28 of Set 13 | chimore
# Processing Record 29 of Set 13 | el alto
# Processing Record 30 of Set 13 | deputatskiy
# Processing Record 31 of Set 13 | chunhuhub
# Processing Record 32 of Set 13 | kangaatsiaq
# Processing Record 33 of Set 13 | jishui
# Processing Record 34 of Set 13 | adre
# Processing Record 35 of Set 13 | atasu
# Processing Record 36 of Set 13 | tiarei
# Processing Record 37 of Set 13 | anahuac
# Processing Record 38 of Set 13 | vao
# Processing Record 39 of Set 13 | berlevag
# Processing Record 40 of Set 13 | salamiyah
# Processing Record 41 of Set 13 | berdigestyakh
# Processing Record 42 of Set 13 | suarez
# Processing Record 43 of Set 13 | leshukonskoye
# Processing Record 44 of Set 13 | yenagoa
# Processing Record 45 of Set 13 | lima
# Processing Record 46 of Set 13 | mackay
# Processing Record 47 of Set 13 | lambontong
# Processing Record 48 of Set 13 | beruwala
# Processing Record 49 of Set 13 | zyryanka
# Processing Record 50 of Set 13 | mao
# Processing Record 1 of Set 14 | san policarpo
# Processing Record 2 of Set 14 | kismayo
# Processing Record 3 of Set 14 | potam
# Processing Record 4 of Set 14 | san pedro
# Processing Record 5 of Set 14 | bergama
# Processing Record 6 of Set 14 | steubenville
# Processing Record 7 of Set 14 | katha
# City not found. Skipping...
# Processing Record 8 of Set 14 | bulgan
# Processing Record 9 of Set 14 | topolevo
# Processing Record 10 of Set 14 | galesong
# Processing Record 11 of Set 14 | fare
# Processing Record 12 of Set 14 | pemangkat
# Processing Record 13 of Set 14 | turan
# Processing Record 14 of Set 14 | nogliki
# Processing Record 15 of Set 14 | zhezkazgan
# Processing Record 16 of Set 14 | birmitrapur
# Processing Record 17 of Set 14 | sinnamary
# Processing Record 18 of Set 14 | almaznyy
# Processing Record 19 of Set 14 | basco
# Processing Record 20 of Set 14 | warrington
# Processing Record 21 of Set 14 | sharlyk
# Processing Record 22 of Set 14 | lucapa
# Processing Record 23 of Set 14 | tiguion
# Processing Record 24 of Set 14 | ocampo
# Processing Record 25 of Set 14 | camocim
# Processing Record 26 of Set 14 | anderson
# Processing Record 27 of Set 14 | comodoro rivadavia
# Processing Record 28 of Set 14 | quilali
# Processing Record 29 of Set 14 | aranos
# Processing Record 30 of Set 14 | curumani
# Processing Record 31 of Set 14 | babat
# Processing Record 32 of Set 14 | richards bay
# Processing Record 33 of Set 14 | inirida
# Processing Record 34 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 35 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 36 of Set 14 | sars
# Processing Record 37 of Set 14 | ariquemes
# Processing Record 38 of Set 14 | pacifica
# Processing Record 39 of Set 14 | begoro
# Processing Record 40 of Set 14 | hammerfest
# Processing Record 41 of Set 14 | kenora
# Processing Record 42 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 14 | awallan
# Processing Record 44 of Set 14 | puerto leguizamo
# Processing Record 45 of Set 14 | changli
# Processing Record 46 of Set 14 | doha
# Processing Record 47 of Set 14 | burns lake
# Processing Record 48 of Set 14 | elat
# Processing Record 49 of Set 14 | praia
# Processing Record 50 of Set 14 | san vicente
# Processing Record 1 of Set 15 | sorland
# Processing Record 2 of Set 15 | burica
# City not found. Skipping...
# Processing Record 3 of Set 15 | tura
# Processing Record 4 of Set 15 | yichun
# Processing Record 5 of Set 15 | cubuk
# Processing Record 6 of Set 15 | samarai
# Processing Record 7 of Set 15 | batticaloa
# Processing Record 8 of Set 15 | socorro
# Processing Record 9 of Set 15 | gorontalo
# Processing Record 10 of Set 15 | teya
# Processing Record 11 of Set 15 | mareeba
# Processing Record 12 of Set 15 | valparaiso
# Processing Record 13 of Set 15 | amahai
# Processing Record 14 of Set 15 | sechura
# Processing Record 15 of Set 15 | igrim
# Processing Record 16 of Set 15 | yunyang
# Processing Record 17 of Set 15 | abu samrah
# Processing Record 18 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 19 of Set 15 | letpadan
# Processing Record 20 of Set 15 | trairi
# Processing Record 21 of Set 15 | busovaca
# Processing Record 22 of Set 15 | vysokogornyy
# Processing Record 23 of Set 15 | kavaratti
# Processing Record 24 of Set 15 | camabatela
# Processing Record 25 of Set 15 | mogadishu
# Processing Record 26 of Set 15 | kachug
# Processing Record 27 of Set 15 | staryy nadym
# Processing Record 28 of Set 15 | nevsehir
# Processing Record 29 of Set 15 | bingol
# Processing Record 30 of Set 15 | sangre grande
# Processing Record 31 of Set 15 | kralendijk
# Processing Record 32 of Set 15 | den helder
# Processing Record 33 of Set 15 | pulivendla
# Processing Record 34 of Set 15 | biak
# Processing Record 35 of Set 15 | coquimbo
# Processing Record 36 of Set 15 | palu
# Processing Record 37 of Set 15 | bud
# Processing Record 38 of Set 15 | namatanai
# Processing Record 39 of Set 15 | juba
# Processing Record 40 of Set 15 | demir hisar
# Processing Record 41 of Set 15 | araioses
# Processing Record 42 of Set 15 | kurayoshi
# Processing Record 43 of Set 15 | nuuk
# Processing Record 44 of Set 15 | ahuimanu
# Processing Record 45 of Set 15 | mehamn
# Processing Record 46 of Set 15 | suffolk
# Processing Record 47 of Set 15 | shingu
# Processing Record 48 of Set 15 | eyl
# Processing Record 49 of Set 15 | sabang
# Processing Record 50 of Set 15 | havre-saint-pierre
# Processing Record 1 of Set 16 | ponta delgada
# Processing Record 2 of Set 16 | baghdad
# Processing Record 3 of Set 16 | tilichiki
# Processing Record 4 of Set 16 | yumen
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 754

# %%
len(city_data)
# Out:
# 694

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Sal Rei      CV  16.1833  -22.9167     73.60        60          75
# 1  Severo-Kurilsk      RU  50.6789  156.1250     23.18        76           5
# 2          Chegem      RU  43.2833   43.1333     19.53        91         100
# 3            Hami      CN  42.8000   93.4500     49.41        24           0
# 4           Bluff      NZ -46.6000  168.3333     55.00        81          10
# 5           Vaini      TO -21.2000 -175.2000     73.56        88          40
# 6        Harrison      US  30.4091  -89.0436     64.06        63           0
# 7        Maragogi      BR  -9.0122  -35.2225     83.41        74          98
# 8         Rikitea      PF -23.1203 -134.9692     78.76        74           6
# 9          Albany      US  42.6001  -73.9662     45.95        70         100
#
#    Wind Speed Current Description
# 0        6.91       broken clouds
# 1        4.70           clear sky
# 2        1.52          light snow
# 3        3.31           clear sky
# 4        1.12           clear sky
# 5        4.61    scattered clouds
# 6        0.00           clear sky
# 7       10.02     overcast clouds
# 8       14.25           clear sky
# 9        1.99     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
