# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7289887da70056aba2314bd34aaab29f

# %%
# Create an endpoint URL for a city.
#city_url = url + "&q=" + "Boston"
#print(city_url)

# %%
# Make a 'Get' request for the city weather.
#city_weather = requests.get(city_url)
#city_weather

# %%
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_weather.status_code
# Out:
# 200

# %%
# Create an endpoint URL for a city.
#city_url = url + "&q=" + "Bston"
#city_weather = requests.get(city_url)
#city_weather

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"base":"stations","main":{"temp":71.08,"feels_like":69.96,"temp_min":60.06,"temp_max":75.51,"pressure":1014,"humidity":44},"visibility":10000,"wind":{"speed":13.8,"deg":120},"clouds":{"all":75},"dt":1647636077,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1647600664,"sunset":1647644013},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 71.08,
#   'feels_like': 69.96,
#   'temp_min': 60.06,
#   'temp_max': 75.51,
#   'pressure': 1014,
#   'humidity': 44},
#  'visibility': 10000,
#  'wind': {'speed': 13.8, 'deg': 120},
#  'clouds': {'all': 75},
#  'dt': 1647636077,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1647600664,
#   'sunset': 1647644013},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7289887da70056aba2314bd34aaab29f&q=Boston

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 71.08,
#   'feels_like': 69.96,
#   'temp_min': 60.06,
#   'temp_max': 75.51,
#   'pressure': 1014,
#   'humidity': 44},
#  'visibility': 10000,
#  'wind': {'speed': 13.8, 'deg': 120},
#  'clouds': {'all': 75},
#  'dt': 1647636077,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1647600664,
#   'sunset': 1647644013},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']
# Out:
# {'type': 2,
#  'id': 2013408,
#  'country': 'US',
#  'sunrise': 1647600664,
#  'sunset': 1647644013}

# %%
boston_data['sys'] ["country"]
# Out:
# 'US'

# %%
boston_data["dt"]
# Out:
# 1647636077

# %%
boston_data["coord"]["lat"]
# Out:
# 42.3584

# %%
boston_data["main"]["temp_max"]
# Out:
# 75.51

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 75.51 44 75 13.8

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 3, 18, 20, 41, 17)

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-03-18 20:41:17'

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 607

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | azle
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | koumac
# Processing Record 6 of Set 1 | coquimbo
# Processing Record 7 of Set 1 | atherton
# Processing Record 8 of Set 1 | paita
# Processing Record 9 of Set 1 | isangel
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | port hardy
# Processing Record 12 of Set 1 | general jose eduvigis diaz
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | kahului
# Processing Record 16 of Set 1 | wairoa
# Processing Record 17 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | hasaki
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | bambous virieux
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | brooks
# Processing Record 26 of Set 1 | predivinsk
# Processing Record 27 of Set 1 | novoagansk
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | swarzedz
# Processing Record 32 of Set 1 | mount isa
# Processing Record 33 of Set 1 | viedma
# Processing Record 34 of Set 1 | wilmington
# Processing Record 35 of Set 1 | itarema
# Processing Record 36 of Set 1 | vila franca do campo
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | bac lieu
# Processing Record 39 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 1 | iquique
# Processing Record 41 of Set 1 | clyde river
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | mount gambier
# Processing Record 44 of Set 1 | bhadrapur
# Processing Record 45 of Set 1 | prince rupert
# Processing Record 46 of Set 1 | sao miguel
# Processing Record 47 of Set 1 | chuy
# Processing Record 48 of Set 1 | naze
# Processing Record 49 of Set 1 | kavaratti
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 1 of Set 2 | cortez
# Processing Record 2 of Set 2 | longyearbyen
# Processing Record 3 of Set 2 | cabo san lucas
# Processing Record 4 of Set 2 | san cristobal
# Processing Record 5 of Set 2 | provideniya
# Processing Record 6 of Set 2 | victor harbor
# Processing Record 7 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | falmouth
# Processing Record 11 of Set 2 | tasiilaq
# Processing Record 12 of Set 2 | guane
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | shingu
# Processing Record 18 of Set 2 | gat
# Processing Record 19 of Set 2 | irbit
# Processing Record 20 of Set 2 | sal rei
# Processing Record 21 of Set 2 | east london
# Processing Record 22 of Set 2 | vestmanna
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | port keats
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | torbay
# Processing Record 28 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 2 | cidreira
# Processing Record 30 of Set 2 | nouadhibou
# Processing Record 31 of Set 2 | kaohsiung
# Processing Record 32 of Set 2 | kamina
# Processing Record 33 of Set 2 | thompson
# Processing Record 34 of Set 2 | chistogorskiy
# Processing Record 35 of Set 2 | kapit
# Processing Record 36 of Set 2 | saint-pierre
# Processing Record 37 of Set 2 | pevek
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | albany
# Processing Record 40 of Set 2 | hobart
# Processing Record 41 of Set 2 | russell
# Processing Record 42 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 2 | kavieng
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | okhotsk
# Processing Record 46 of Set 2 | zhezkazgan
# Processing Record 47 of Set 2 | moree
# Processing Record 48 of Set 2 | golden
# Processing Record 49 of Set 2 | nongpoh
# Processing Record 50 of Set 2 | vostok
# Processing Record 1 of Set 3 | lebu
# Processing Record 2 of Set 3 | norman wells
# Processing Record 3 of Set 3 | reconquista
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | dingle
# Processing Record 6 of Set 3 | bubaque
# Processing Record 7 of Set 3 | adrar
# Processing Record 8 of Set 3 | sakakah
# Processing Record 9 of Set 3 | namatanai
# Processing Record 10 of Set 3 | mahebourg
# Processing Record 11 of Set 3 | champerico
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | alofi
# Processing Record 14 of Set 3 | esperance
# Processing Record 15 of Set 3 | saint-philippe
# Processing Record 16 of Set 3 | bethel
# Processing Record 17 of Set 3 | faya
# Processing Record 18 of Set 3 | esso
# Processing Record 19 of Set 3 | the valley
# Processing Record 20 of Set 3 | biak
# Processing Record 21 of Set 3 | klaksvik
# Processing Record 22 of Set 3 | tiksi
# Processing Record 23 of Set 3 | makakilo city
# Processing Record 24 of Set 3 | hithadhoo
# Processing Record 25 of Set 3 | gigmoto
# Processing Record 26 of Set 3 | ferme-neuve
# Processing Record 27 of Set 3 | carsamba
# Processing Record 28 of Set 3 | yakeshi
# Processing Record 29 of Set 3 | imeni poliny osipenko
# Processing Record 30 of Set 3 | port hedland
# Processing Record 31 of Set 3 | jamestown
# Processing Record 32 of Set 3 | dehui
# Processing Record 33 of Set 3 | bela palanka
# Processing Record 34 of Set 3 | sambava
# Processing Record 35 of Set 3 | port blair
# Processing Record 36 of Set 3 | san andres
# Processing Record 37 of Set 3 | talnakh
# Processing Record 38 of Set 3 | katangli
# Processing Record 39 of Set 3 | airai
# Processing Record 40 of Set 3 | ponta do sol
# Processing Record 41 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 3 | ahipara
# Processing Record 44 of Set 3 | metehara
# City not found. Skipping...
# Processing Record 45 of Set 3 | muscat
# Processing Record 46 of Set 3 | hambantota
# Processing Record 47 of Set 3 | nikolskoye
# Processing Record 48 of Set 3 | pedernales
# Processing Record 49 of Set 3 | coolum beach
# Processing Record 50 of Set 3 | cherskiy
# Processing Record 1 of Set 4 | niort
# Processing Record 2 of Set 4 | lorengau
# Processing Record 3 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 4 | makat
# Processing Record 5 of Set 4 | joshimath
# Processing Record 6 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 4 | pisco
# Processing Record 9 of Set 4 | castro
# Processing Record 10 of Set 4 | luderitz
# Processing Record 11 of Set 4 | constantine
# Processing Record 12 of Set 4 | verkh-usugli
# Processing Record 13 of Set 4 | kudahuvadhoo
# Processing Record 14 of Set 4 | nanortalik
# Processing Record 15 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 4 | igarka
# Processing Record 17 of Set 4 | upernavik
# Processing Record 18 of Set 4 | port alfred
# Processing Record 19 of Set 4 | faanui
# Processing Record 20 of Set 4 | kailua
# Processing Record 21 of Set 4 | latung
# Processing Record 22 of Set 4 | kokstad
# Processing Record 23 of Set 4 | kaka
# Processing Record 24 of Set 4 | lompoc
# Processing Record 25 of Set 4 | mount pleasant
# Processing Record 26 of Set 4 | santa marta
# Processing Record 27 of Set 4 | saint george
# Processing Record 28 of Set 4 | sorland
# Processing Record 29 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 4 | barra do garcas
# Processing Record 31 of Set 4 | kishtwar
# Processing Record 32 of Set 4 | northam
# Processing Record 33 of Set 4 | abu dhabi
# Processing Record 34 of Set 4 | christchurch
# Processing Record 35 of Set 4 | leningradskiy
# Processing Record 36 of Set 4 | beringovskiy
# Processing Record 37 of Set 4 | yershov
# Processing Record 38 of Set 4 | cape town
# Processing Record 39 of Set 4 | yulara
# Processing Record 40 of Set 4 | iqaluit
# Processing Record 41 of Set 4 | saint anthony
# Processing Record 42 of Set 4 | henties bay
# Processing Record 43 of Set 4 | burgersdorp
# Processing Record 44 of Set 4 | bilma
# Processing Record 45 of Set 4 | nizwa
# Processing Record 46 of Set 4 | fort wellington
# Processing Record 47 of Set 4 | salina
# Processing Record 48 of Set 4 | chokurdakh
# Processing Record 49 of Set 4 | nemuro
# Processing Record 50 of Set 4 | ladario
# Processing Record 1 of Set 5 | sisimiut
# Processing Record 2 of Set 5 | chumikan
# Processing Record 3 of Set 5 | nagar karnul
# Processing Record 4 of Set 5 | camacha
# Processing Record 5 of Set 5 | gamba
# Processing Record 6 of Set 5 | iraquara
# Processing Record 7 of Set 5 | eleon
# City not found. Skipping...
# Processing Record 8 of Set 5 | te anau
# Processing Record 9 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 5 | victoria
# Processing Record 11 of Set 5 | rio gallegos
# Processing Record 12 of Set 5 | nkayi
# Processing Record 13 of Set 5 | fort nelson
# Processing Record 14 of Set 5 | ewa beach
# Processing Record 15 of Set 5 | rabo de peixe
# Processing Record 16 of Set 5 | gobabis
# Processing Record 17 of Set 5 | ormara
# Processing Record 18 of Set 5 | olafsvik
# Processing Record 19 of Set 5 | touros
# Processing Record 20 of Set 5 | rawson
# Processing Record 21 of Set 5 | honningsvag
# Processing Record 22 of Set 5 | avera
# Processing Record 23 of Set 5 | pangoa
# Processing Record 24 of Set 5 | hodmezovasarhely
# Processing Record 25 of Set 5 | havre-saint-pierre
# Processing Record 26 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 5 | humberto de campos
# Processing Record 28 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 5 | klyuchi
# Processing Record 30 of Set 5 | yaan
# Processing Record 31 of Set 5 | marsa matruh
# Processing Record 32 of Set 5 | georgetown
# Processing Record 33 of Set 5 | west wendover
# Processing Record 34 of Set 5 | luga
# Processing Record 35 of Set 5 | veraval
# Processing Record 36 of Set 5 | kaitangata
# Processing Record 37 of Set 5 | george town
# Processing Record 38 of Set 5 | puerto madryn
# Processing Record 39 of Set 5 | lima
# Processing Record 40 of Set 5 | geraldton
# Processing Record 41 of Set 5 | bengkulu
# Processing Record 42 of Set 5 | guerrero negro
# Processing Record 43 of Set 5 | luwuk
# Processing Record 44 of Set 5 | vardo
# Processing Record 45 of Set 5 | zhmerynka
# Processing Record 46 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 47 of Set 5 | husavik
# Processing Record 48 of Set 5 | meulaboh
# Processing Record 49 of Set 5 | paramonga
# Processing Record 50 of Set 5 | taltal
# Processing Record 1 of Set 6 | vanimo
# Processing Record 2 of Set 6 | pauini
# Processing Record 3 of Set 6 | walvis bay
# Processing Record 4 of Set 6 | porto walter
# Processing Record 5 of Set 6 | inuvik
# Processing Record 6 of Set 6 | alihe
# Processing Record 7 of Set 6 | sao joao da barra
# Processing Record 8 of Set 6 | guna
# Processing Record 9 of Set 6 | konya
# Processing Record 10 of Set 6 | usagara
# Processing Record 11 of Set 6 | port-cartier
# Processing Record 12 of Set 6 | sinnamary
# Processing Record 13 of Set 6 | balykshi
# Processing Record 14 of Set 6 | portland
# Processing Record 15 of Set 6 | danville
# Processing Record 16 of Set 6 | marathon
# Processing Record 17 of Set 6 | grand gaube
# Processing Record 18 of Set 6 | haines junction
# Processing Record 19 of Set 6 | kilindoni
# Processing Record 20 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 21 of Set 6 | ola
# Processing Record 22 of Set 6 | san patricio
# Processing Record 23 of Set 6 | bayji
# Processing Record 24 of Set 6 | lata
# Processing Record 25 of Set 6 | gayny
# Processing Record 26 of Set 6 | hohhot
# Processing Record 27 of Set 6 | malanje
# Processing Record 28 of Set 6 | bongandanga
# Processing Record 29 of Set 6 | lac du bonnet
# Processing Record 30 of Set 6 | saint-georges
# Processing Record 31 of Set 6 | saint-augustin
# Processing Record 32 of Set 6 | ostrovnoy
# Processing Record 33 of Set 6 | skegness
# Processing Record 34 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 35 of Set 6 | hervey bay
# Processing Record 36 of Set 6 | sao filipe
# Processing Record 37 of Set 6 | svetlaya
# Processing Record 38 of Set 6 | kruisfontein
# Processing Record 39 of Set 6 | san policarpo
# Processing Record 40 of Set 6 | margate
# Processing Record 41 of Set 6 | zeya
# Processing Record 42 of Set 6 | tabou
# Processing Record 43 of Set 6 | sindand
# City not found. Skipping...
# Processing Record 44 of Set 6 | burica
# City not found. Skipping...
# Processing Record 45 of Set 6 | sebinkarahisar
# Processing Record 46 of Set 6 | springdale
# Processing Record 47 of Set 6 | komsomolskiy
# Processing Record 48 of Set 6 | karratha
# Processing Record 49 of Set 6 | umm lajj
# Processing Record 50 of Set 6 | yerbogachen
# Processing Record 1 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 2 of Set 7 | rock sound
# Processing Record 3 of Set 7 | mana
# Processing Record 4 of Set 7 | krasnoselkup
# Processing Record 5 of Set 7 | padang
# Processing Record 6 of Set 7 | khagrachari
# City not found. Skipping...
# Processing Record 7 of Set 7 | usoke
# Processing Record 8 of Set 7 | bonavista
# Processing Record 9 of Set 7 | pindiga
# Processing Record 10 of Set 7 | barahona
# Processing Record 11 of Set 7 | souillac
# Processing Record 12 of Set 7 | sauteurs
# Processing Record 13 of Set 7 | tuatapere
# Processing Record 14 of Set 7 | kalmunai
# Processing Record 15 of Set 7 | liverpool
# Processing Record 16 of Set 7 | bembereke
# Processing Record 17 of Set 7 | epe
# Processing Record 18 of Set 7 | kaeo
# Processing Record 19 of Set 7 | salalah
# Processing Record 20 of Set 7 | huancabamba
# Processing Record 21 of Set 7 | barcelona
# Processing Record 22 of Set 7 | aykhal
# Processing Record 23 of Set 7 | kultuk
# Processing Record 24 of Set 7 | develi
# Processing Record 25 of Set 7 | narsaq
# Processing Record 26 of Set 7 | alcala la real
# Processing Record 27 of Set 7 | fomboni
# Processing Record 28 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 7 | poya
# Processing Record 30 of Set 7 | qaqortoq
# Processing Record 31 of Set 7 | aklavik
# Processing Record 32 of Set 7 | sun city west
# Processing Record 33 of Set 7 | devils lake
# Processing Record 34 of Set 7 | maarianhamina
# Processing Record 35 of Set 7 | preobrazheniye
# Processing Record 36 of Set 7 | pimentel
# Processing Record 37 of Set 7 | maniitsoq
# Processing Record 38 of Set 7 | tarko-sale
# Processing Record 39 of Set 7 | aranos
# Processing Record 40 of Set 7 | delhi
# Processing Record 41 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 7 | hofn
# Processing Record 43 of Set 7 | arraial do cabo
# Processing Record 44 of Set 7 | mandla
# Processing Record 45 of Set 7 | fortuna
# Processing Record 46 of Set 7 | chapais
# Processing Record 47 of Set 7 | tchibanga
# Processing Record 48 of Set 7 | dangriga
# Processing Record 49 of Set 7 | beihai
# Processing Record 50 of Set 7 | ankang
# Processing Record 1 of Set 8 | udachnyy
# Processing Record 2 of Set 8 | ust-maya
# Processing Record 3 of Set 8 | severo-kurilsk
# Processing Record 4 of Set 8 | clearwater
# Processing Record 5 of Set 8 | kamaishi
# Processing Record 6 of Set 8 | mirnyy
# Processing Record 7 of Set 8 | vitim
# Processing Record 8 of Set 8 | benito juarez
# Processing Record 9 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 8 | limbang
# Processing Record 11 of Set 8 | neyshabur
# Processing Record 12 of Set 8 | banjar
# Processing Record 13 of Set 8 | lengshuijiang
# Processing Record 14 of Set 8 | vao
# Processing Record 15 of Set 8 | mujiayingzi
# Processing Record 16 of Set 8 | cairns
# Processing Record 17 of Set 8 | tura
# Processing Record 18 of Set 8 | xapuri
# Processing Record 19 of Set 8 | kawalu
# Processing Record 20 of Set 8 | wenling
# Processing Record 21 of Set 8 | solton
# Processing Record 22 of Set 8 | havelock
# Processing Record 23 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 8 | codrington
# Processing Record 26 of Set 8 | cabedelo
# Processing Record 27 of Set 8 | carutapera
# Processing Record 28 of Set 8 | gainesville
# Processing Record 29 of Set 8 | sembe
# Processing Record 30 of Set 8 | aberdeen
# Processing Record 31 of Set 8 | muli
# Processing Record 32 of Set 8 | valley city
# Processing Record 33 of Set 8 | zhigansk
# Processing Record 34 of Set 8 | surt
# Processing Record 35 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 36 of Set 8 | newport
# Processing Record 37 of Set 8 | sao miguel do araguaia
# Processing Record 38 of Set 8 | mega
# Processing Record 39 of Set 8 | luena
# Processing Record 40 of Set 8 | berlevag
# Processing Record 41 of Set 8 | ecija
# Processing Record 42 of Set 8 | tukrah
# Processing Record 43 of Set 8 | conceicao do araguaia
# Processing Record 44 of Set 8 | ilulissat
# Processing Record 45 of Set 8 | necochea
# Processing Record 46 of Set 8 | tambopata
# Processing Record 47 of Set 8 | jati
# Processing Record 48 of Set 8 | douglas
# Processing Record 49 of Set 8 | castelldefels
# Processing Record 50 of Set 8 | bathsheba
# Processing Record 1 of Set 9 | looc
# Processing Record 2 of Set 9 | tiarei
# Processing Record 3 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 4 of Set 9 | ayan
# Processing Record 5 of Set 9 | zaraza
# Processing Record 6 of Set 9 | beaumont
# Processing Record 7 of Set 9 | comodoro rivadavia
# Processing Record 8 of Set 9 | umm kaddadah
# Processing Record 9 of Set 9 | flinders
# Processing Record 10 of Set 9 | inhambane
# Processing Record 11 of Set 9 | awjilah
# Processing Record 12 of Set 9 | fairmont
# Processing Record 13 of Set 9 | eyl
# Processing Record 14 of Set 9 | yarada
# Processing Record 15 of Set 9 | orocue
# Processing Record 16 of Set 9 | petrovskoye
# Processing Record 17 of Set 9 | khandyga
# Processing Record 18 of Set 9 | hovd
# Processing Record 19 of Set 9 | oktyabrskoye
# Processing Record 20 of Set 9 | sarangpur
# Processing Record 21 of Set 9 | omsukchan
# Processing Record 22 of Set 9 | lagoa
# Processing Record 23 of Set 9 | port lincoln
# Processing Record 24 of Set 9 | aguimes
# Processing Record 25 of Set 9 | nome
# Processing Record 26 of Set 9 | lensk
# Processing Record 27 of Set 9 | itaueira
# Processing Record 28 of Set 9 | diapaga
# Processing Record 29 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 9 | asosa
# Processing Record 31 of Set 9 | borshchiv
# Processing Record 32 of Set 9 | santana do livramento
# Processing Record 33 of Set 9 | sidi ali
# Processing Record 34 of Set 9 | aquiraz
# Processing Record 35 of Set 9 | itaguai
# Processing Record 36 of Set 9 | bud
# Processing Record 37 of Set 9 | stromness
# Processing Record 38 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 39 of Set 9 | chicama
# Processing Record 40 of Set 9 | bradford
# Processing Record 41 of Set 9 | matamoros
# Processing Record 42 of Set 9 | hampton
# Processing Record 43 of Set 9 | villagarzon
# Processing Record 44 of Set 9 | ulladulla
# Processing Record 45 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 46 of Set 9 | poum
# Processing Record 47 of Set 9 | sassandra
# Processing Record 48 of Set 9 | mao
# Processing Record 49 of Set 9 | agirish
# Processing Record 50 of Set 9 | dargaville
# Processing Record 1 of Set 10 | dudinka
# Processing Record 2 of Set 10 | paris
# Processing Record 3 of Set 10 | arrifes
# Processing Record 4 of Set 10 | potgietersrus
# City not found. Skipping...
# Processing Record 5 of Set 10 | lapua
# Processing Record 6 of Set 10 | vila velha
# Processing Record 7 of Set 10 | saldanha
# Processing Record 8 of Set 10 | bonthe
# Processing Record 9 of Set 10 | los algarrobos
# Processing Record 10 of Set 10 | maceio
# Processing Record 11 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 10 | waipawa
# Processing Record 13 of Set 10 | dunedin
# Processing Record 14 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 10 | ixtapa
# Processing Record 16 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 17 of Set 10 | calama
# Processing Record 18 of Set 10 | wajima
# Processing Record 19 of Set 10 | jiangmen
# Processing Record 20 of Set 10 | sitka
# Processing Record 21 of Set 10 | mitsamiouli
# Processing Record 22 of Set 10 | redmond
# Processing Record 23 of Set 10 | oda
# Processing Record 24 of Set 10 | dombarovskiy
# Processing Record 25 of Set 10 | linjiang
# Processing Record 26 of Set 10 | la grande
# Processing Record 27 of Set 10 | moindou
# Processing Record 28 of Set 10 | lebedyn
# Processing Record 29 of Set 10 | cockburn town
# Processing Record 30 of Set 10 | warud
# Processing Record 31 of Set 10 | poshekhonye
# Processing Record 32 of Set 10 | flin flon
# Processing Record 33 of Set 10 | nishihara
# Processing Record 34 of Set 10 | muisne
# Processing Record 35 of Set 10 | pak phanang
# Processing Record 36 of Set 10 | agua dulce
# Processing Record 37 of Set 10 | kosino
# Processing Record 38 of Set 10 | lesozavodsk
# Processing Record 39 of Set 10 | mayo
# Processing Record 40 of Set 10 | omboue
# Processing Record 41 of Set 10 | takoradi
# Processing Record 42 of Set 10 | shunyi
# Processing Record 43 of Set 10 | kirakira
# Processing Record 44 of Set 10 | kindu
# Processing Record 45 of Set 10 | kjollefjord
# Processing Record 46 of Set 10 | waitati
# Processing Record 47 of Set 10 | javanrud
# Processing Record 48 of Set 10 | port arthur
# Processing Record 49 of Set 10 | teknaf
# Processing Record 50 of Set 10 | la cruz
# Processing Record 1 of Set 11 | verkhnevilyuysk
# Processing Record 2 of Set 11 | funtua
# Processing Record 3 of Set 11 | sur
# Processing Record 4 of Set 11 | maracas
# Processing Record 5 of Set 11 | valparaiso
# Processing Record 6 of Set 11 | alvaraes
# Processing Record 7 of Set 11 | asau
# Processing Record 8 of Set 11 | diofior
# Processing Record 9 of Set 11 | stephenville
# Processing Record 10 of Set 11 | kamalia
# Processing Record 11 of Set 11 | saleilua
# City not found. Skipping...
# Processing Record 12 of Set 11 | tokur
# Processing Record 13 of Set 11 | resplendor
# Processing Record 14 of Set 11 | hastings
# Processing Record 15 of Set 11 | mukhen
# Processing Record 16 of Set 11 | praia da vitoria
# Processing Record 17 of Set 11 | soyo
# Processing Record 18 of Set 11 | leek
# Processing Record 19 of Set 11 | olinda
# Processing Record 20 of Set 11 | neka
# Processing Record 21 of Set 11 | ukiah
# Processing Record 22 of Set 11 | bandarbeyla
# Processing Record 23 of Set 11 | saint-francois
# Processing Record 24 of Set 11 | colimes
# Processing Record 25 of Set 11 | tezu
# Processing Record 26 of Set 11 | pacific grove
# Processing Record 27 of Set 11 | phrai bung
# City not found. Skipping...
# Processing Record 28 of Set 11 | kismayo
# Processing Record 29 of Set 11 | bakchar
# Processing Record 30 of Set 11 | mezhdurechensk
# Processing Record 31 of Set 11 | tuensang
# Processing Record 32 of Set 11 | havoysund
# Processing Record 33 of Set 11 | galesong
# Processing Record 34 of Set 11 | katherine
# Processing Record 35 of Set 11 | templin
# Processing Record 36 of Set 11 | aasiaat
# Processing Record 37 of Set 11 | caravelas
# Processing Record 38 of Set 11 | la ronge
# Processing Record 39 of Set 11 | diego de almagro
# Processing Record 40 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 11 | tual
# Processing Record 42 of Set 11 | petrolandia
# City not found. Skipping...
# Processing Record 43 of Set 11 | bosaso
# Processing Record 44 of Set 11 | yabrud
# Processing Record 45 of Set 11 | sistranda
# Processing Record 46 of Set 11 | itoman
# Processing Record 47 of Set 11 | richards bay
# Processing Record 48 of Set 11 | ankazoabo
# Processing Record 49 of Set 11 | dutlwe
# Processing Record 50 of Set 11 | hami
# Processing Record 1 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 2 of Set 12 | jumla
# Processing Record 3 of Set 12 | alnashi
# Processing Record 4 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 12 | zambezi
# Processing Record 6 of Set 12 | ancud
# Processing Record 7 of Set 12 | acapulco
# Processing Record 8 of Set 12 | marawi
# Processing Record 9 of Set 12 | korhogo
# Processing Record 10 of Set 12 | port augusta
# Processing Record 11 of Set 12 | izhma
# Processing Record 12 of Set 12 | ankpa
# Processing Record 13 of Set 12 | binghamton
# Processing Record 14 of Set 12 | morant bay
# Processing Record 15 of Set 12 | tazovskiy
# Processing Record 16 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 12 | lexington
# Processing Record 18 of Set 12 | samfya
# Processing Record 19 of Set 12 | sucre
# Processing Record 20 of Set 12 | chokwe
# Processing Record 21 of Set 12 | talaya
# Processing Record 22 of Set 12 | tessalit
# Processing Record 23 of Set 12 | eskisehir
# Processing Record 24 of Set 12 | kostino
# Processing Record 25 of Set 12 | cedar city
# Processing Record 26 of Set 12 | oxapampa
# Processing Record 27 of Set 12 | acarau
# Processing Record 28 of Set 12 | san quintin
# Processing Record 29 of Set 12 | alice springs
# Processing Record 30 of Set 12 | paraiso
# Processing Record 31 of Set 12 | de pere
# Processing Record 32 of Set 12 | daru
# Processing Record 33 of Set 12 | xining
# Processing Record 34 of Set 12 | ekhabi
# Processing Record 35 of Set 12 | verkhoyansk
# Processing Record 36 of Set 12 | hualmay
# Processing Record 37 of Set 12 | listvyanskiy
# Processing Record 38 of Set 12 | derzhavinsk
# Processing Record 39 of Set 12 | chesley
# Processing Record 40 of Set 12 | quebec
# Processing Record 41 of Set 12 | jibuti
# Processing Record 42 of Set 12 | palasa
# Processing Record 43 of Set 12 | igboho
# Processing Record 44 of Set 12 | balakhta
# Processing Record 45 of Set 12 | eureka
# Processing Record 46 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 12 | zabol
# Processing Record 48 of Set 12 | juneau
# Processing Record 49 of Set 12 | kaabong
# Processing Record 50 of Set 12 | maragogi
# Processing Record 1 of Set 13 | lichinga
# Processing Record 2 of Set 13 | fallon
# Processing Record 3 of Set 13 | gulariya
# Processing Record 4 of Set 13 | gweta
# Processing Record 5 of Set 13 | conde
# Processing Record 6 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 13 | yar-sale
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Butaritari   3.0707  172.7902     80.53        81          23       19.15
# 1         Azle  32.8951  -97.5459     66.67        36          20       19.57
# 2  Yellowknife  62.4560 -114.3525     24.42        80          75        4.61
# 3       Kodiak  57.7900 -152.4072     33.31        75         100       13.80
# 4       Koumac -20.5667  164.2833     79.86        76          54        3.18
# 5     Coquimbo -29.9533  -71.3436     67.73        72           0       16.11
# 6     Atherton  53.5237   -2.4935     52.25        70           8        3.00
# 7        Paita  -5.0892  -81.1144     79.81        67          12       18.81
# 8      Isangel -19.5500  169.2667     82.42        73         100        3.58
# 9        Vaini -21.2000 -175.2000     78.96        83         100       17.27
#
#   Country                 Date
# 0      KI  2022-03-18 20:46:45
# 1      US  2022-03-18 20:46:07
# 2      CA  2022-03-18 20:45:15
# 3      US  2022-03-18 20:46:46
# 4      NC  2022-03-18 20:46:47
# 5      CL  2022-03-18 20:43:16
# 6      GB  2022-03-18 20:46:47
# 7      PE  2022-03-18 20:46:47
# 8      VU  2022-03-18 20:46:48
# 9      TO  2022-03-18 20:46:48

# %%
new_column_order = ["City", "Country", "Date", "Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]

#City=1
#Cloudlness=2
#Country=3
#Date=4
#Humidty=5
#Lat=6
#Lng=7
#Max Temp=8
#Wind Speed=9

city_data_df = city_data_df[new_column_order]


city_data_df.head(10)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0   Butaritari      KI  2022-03-18 20:46:45   3.0707  172.7902     80.53
# 1         Azle      US  2022-03-18 20:46:07  32.8951  -97.5459     66.67
# 2  Yellowknife      CA  2022-03-18 20:45:15  62.4560 -114.3525     24.42
# 3       Kodiak      US  2022-03-18 20:46:46  57.7900 -152.4072     33.31
# 4       Koumac      NC  2022-03-18 20:46:47 -20.5667  164.2833     79.86
# 5     Coquimbo      CL  2022-03-18 20:43:16 -29.9533  -71.3436     67.73
# 6     Atherton      GB  2022-03-18 20:46:47  53.5237   -2.4935     52.25
# 7        Paita      PE  2022-03-18 20:46:47  -5.0892  -81.1144     79.81
# 8      Isangel      VU  2022-03-18 20:46:48 -19.5500  169.2667     82.42
# 9        Vaini      TO  2022-03-18 20:46:48 -21.2000 -175.2000     78.96
#
#    Humidity  Cloudiness  Wind Speed
# 0        81          23       19.15
# 1        36          20       19.57
# 2        80          75        4.61
# 3        75         100       13.80
# 4        76          54        3.18
# 5        72           0       16.11
# 6        70           8        3.00
# 7        67          12       18.81
# 8        73         100        3.58
# 9        83         100       17.27

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1647637538.465217

# %%
today = time.strftime("%x")
today

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/ln/fkq0ljkj425f2gdzb_2xzqvc0000gn/T/ipykernel_2890/1098817227.py in <module>
#       5 max_temp = city_data_df["Max Temp"]
#       6 # Assign the figure variable.
# ----> 7 fig = gmaps.figure()
#       8 # Assign the heatmap variable.
#       9 heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
#
# NameError: name 'gmaps' is not defined
